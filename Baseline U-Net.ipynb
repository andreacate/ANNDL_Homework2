# %% [markdown]
# ## ☁️ Connect G-Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Homework 2 AN2DL condivisa/Final Notebooks/Baseline U-Net (Cleaned dataset)
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/.shortcut-targets-by-id/1SjZ_-XjkG_FsuR9orhSxIGp-dNxNdzS1/Homework 2 AN2DL condivisa/Final Notebooks/Baseline U-Net (Cleaned dataset)

# %% [markdown]
# ## ⚒️ Import libraries

# %%
# Set seed for reproducibility
seed = 42

# Import necessary libraries
import os

# Set environment variables before importing modules
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

# Import necessary modules
import logging
import random
import numpy as np

# Set seeds for random number generators in NumPy and Python
np.random.seed(seed)
random.seed(seed)

# Import TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl

# Set seed for TensorFlow
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# Reduce TensorFlow verbosity
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# Print TensorFlow version
print(tf.__version__)

# Import other libraries
import os
import math
from PIL import Image
from keras import backend as K
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline
# Out:
# 2.17.1

# %% [markdown]
# ## 📊 Load data (no 👽)

# %%
data = np.load("../../Datasets/Dataset_without_aliens.npz")
training_set = data["training_set"]

X_train = training_set[0, :]
y_train = training_set[1, :]

X_test = data["test_set"]

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
# Out:
# (2505, 64, 128)
# (2505, 64, 128)
# (10022, 64, 128)

# %% [markdown]
# ## 📈 Parameters

# %%
# Set batch size for training
BATCH_SIZE = 64

# Set learning rate for the optimiser
LEARNING_RATE = 1e-3

# Set early stopping patience threshold
PATIENCE = 10

# Set maximum number of training epochs
EPOCHS = 1000

# Number of classes
NUM_CLASSES = 5

# %% [markdown]
# ## Building dataset

# %%
# Split the paths (not the data) into training, validation, and test sets
print("Splitting data...")
train_val_img, test_img, train_val_lbl, test_lbl = train_test_split(
    X_train, y_train, test_size=0.1, random_state=seed
)

train_img, val_img, train_lbl, val_lbl = train_test_split(
    train_val_img, train_val_lbl, test_size=0.1, random_state=seed
)

print("Data splitted!")

print(f"\nNumber of images:")
print(f"Train: {len(train_img)}")
print(f"Validation: {len(val_img)}")
print(f"Test: {len(test_img)}")

del train_val_img, train_val_lbl
# Out:
# Splitting data...
# Data splitted!
#
# Number of images:
# Train: 2028
# Validation: 226
# Test: 251

# %%
def make_dataset(image_paths, label_paths, batch_size, shuffle=True, augment=False, seed=None):
    """
    Create a memory-efficient TensorFlow dataset.
    """
    # Create dataset from file paths
    dataset = tf.data.Dataset.from_tensor_slices((image_paths, label_paths))

    if shuffle:
        dataset = dataset.shuffle(buffer_size=batch_size * 2, seed=seed)

    # Batch the data
    dataset = dataset.batch(batch_size, drop_remainder=False)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)

    return dataset

# %%
# Create the datasets
print("Creating datasets...")

train_dataset = make_dataset(
    train_img, train_lbl,
    batch_size=BATCH_SIZE,
    shuffle=True,
    augment=True,
    seed=seed
)

val_dataset = make_dataset(
    val_img, val_lbl,
    batch_size=BATCH_SIZE,
    shuffle=False
)

test_dataset = make_dataset(
    test_img, test_lbl,
    batch_size=BATCH_SIZE,
    shuffle=False
)


print("Datasets created!")

# Check the shape of the data
for images, labels in train_dataset.take(1):
    input_shape = images.shape[1:]
    print(f"\nInput shape: {input_shape}")
    print("Images shape:", images.shape)
    print("Labels shape:", labels.shape)
    print("Labels dtype:", labels.dtype)
    break
# Out:
# Creating datasets...
# Datasets created!
#
# Input shape: (64, 128)
# Images shape: (64, 64, 128)
# Labels shape: (64, 64, 128)
# Labels dtype: <dtype: 'float64'>

# %% [markdown]
# ## Network

# %%
def unet_block(input_tensor, filters, kernel_size=3, activation='relu', stack=2, name=''):
    # Initialise the input tensor
    x = input_tensor

    # Apply a sequence of Conv2D, Batch Normalisation, and Activation layers for the specified number of stacks
    for i in range(stack):
        x = tfkl.Conv2D(filters, kernel_size=kernel_size, padding='same', name=name + 'conv' + str(i + 1))(x)
        x = tfkl.BatchNormalization(name=name + 'bn' + str(i + 1))(x)
        x = tfkl.Activation(activation, name=name + 'activation' + str(i + 1))(x)

    # Return the transformed tensor
    return x

# %%
def get_unet_model(input_shape=(64, 128, 1), num_classes=NUM_CLASSES, seed=seed):
    tf.random.set_seed(seed)
    input_layer = tfkl.Input(shape=input_shape, name='input_layer')

    # Downsampling path
    down_block_1 = unet_block(input_layer, 32, name='down_block1_')
    d1 = tfkl.MaxPooling2D()(down_block_1)

    down_block_2 = unet_block(d1, 64, name='down_block2_')
    d2 = tfkl.MaxPooling2D()(down_block_2)

    # Bottleneck
    bottleneck = unet_block(d2, 128, name='bottleneck')

    # Upsampling path
    u1 = tfkl.UpSampling2D()(bottleneck)
    u1 = tfkl.Concatenate()([u1, down_block_2])
    u1 = unet_block(u1, 64, name='up_block1_')

    u2 = tfkl.UpSampling2D()(u1)
    u2 = tfkl.Concatenate()([u2, down_block_1])
    u2 = unet_block(u2, 32, name='up_block2_')

    # Output Layer
    output_layer = tfkl.Conv2D(num_classes, kernel_size=1, padding='same', activation="softmax", name='output_layer')(u2)

    model = tf.keras.Model(inputs=input_layer, outputs=output_layer, name='UNet')
    return model

# %%
model = get_unet_model()

# Print a detailed summary of the model with expanded nested layers and trainable parameters.
model.summary(expand_nested=True, show_trainable=True)

# Generate and display a graphical representation of the model architecture.
tf.keras.utils.plot_model(model, show_trainable=True, expand_nested=True, dpi=70)
# Out:
# Model: "UNet"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ Layer (type)           ┃ Output Shape         ┃      Param # ┃ Connected to        ┃ Traina… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ input_layer            │ (None, 64, 128, 1)   │            0 │ -                   │    -    │
# │ (InputLayer)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_conv1      │ (None, 64, 128, 32)  │          320 │ input_layer[0][0]   │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_bn1        │ (None, 64, 128, 32)  │          128 │ down_block1_conv1[… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_activatio… │ (None, 64, 128, 32)  │            0 │ down_block1_bn1[0]… │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_conv2      │ (None, 64, 128, 32)  │        9,248 │ down_block1_activa… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_bn2        │ (None, 64, 128, 32)  │          128 │ down_block1_conv2[… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_activatio… │ (None, 64, 128, 32)  │            0 │ down_block1_bn2[0]… │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ max_pooling2d          │ (None, 32, 64, 32)   │            0 │ down_block1_activa… │    -    │
# │ (MaxPooling2D)         │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_conv1      │ (None, 32, 64, 64)   │       18,496 │ max_pooling2d[0][0] │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_bn1        │ (None, 32, 64, 64)   │          256 │ down_block2_conv1[… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_activatio… │ (None, 32, 64, 64)   │            0 │ down_block2_bn1[0]… │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_conv2      │ (None, 32, 64, 64)   │       36,928 │ down_block2_activa… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_bn2        │ (None, 32, 64, 64)   │          256 │ down_block2_conv2[… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_activatio… │ (None, 32, 64, 64)   │            0 │ down_block2_bn2[0]… │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ max_pooling2d_1        │ (None, 16, 32, 64)   │            0 │ down_block2_activa… │    -    │
# │ (MaxPooling2D)         │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckconv1        │ (None, 16, 32, 128)  │       73,856 │ max_pooling2d_1[0]… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckbn1          │ (None, 16, 32, 128)  │          512 │ bottleneckconv1[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckactivation1  │ (None, 16, 32, 128)  │            0 │ bottleneckbn1[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckconv2        │ (None, 16, 32, 128)  │      147,584 │ bottleneckactivati… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckbn2          │ (None, 16, 32, 128)  │          512 │ bottleneckconv2[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckactivation2  │ (None, 16, 32, 128)  │            0 │ bottleneckbn2[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_sampling2d          │ (None, 32, 64, 128)  │            0 │ bottleneckactivati… │    -    │
# │ (UpSampling2D)         │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ concatenate            │ (None, 32, 64, 192)  │            0 │ up_sampling2d[0][0… │    -    │
# │ (Concatenate)          │                      │              │ down_block2_activa… │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_conv1        │ (None, 32, 64, 64)   │      110,656 │ concatenate[0][0]   │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_bn1          │ (None, 32, 64, 64)   │          256 │ up_block1_conv1[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_activation1  │ (None, 32, 64, 64)   │            0 │ up_block1_bn1[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_conv2        │ (None, 32, 64, 64)   │       36,928 │ up_block1_activati… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_bn2          │ (None, 32, 64, 64)   │          256 │ up_block1_conv2[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_activation2  │ (None, 32, 64, 64)   │            0 │ up_block1_bn2[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_sampling2d_1        │ (None, 64, 128, 64)  │            0 │ up_block1_activati… │    -    │
# │ (UpSampling2D)         │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ concatenate_1          │ (None, 64, 128, 96)  │            0 │ up_sampling2d_1[0]… │    -    │
# │ (Concatenate)          │                      │              │ down_block1_activa… │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_conv1        │ (None, 64, 128, 32)  │       27,680 │ concatenate_1[0][0] │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_bn1          │ (None, 64, 128, 32)  │          128 │ up_block2_conv1[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_activation1  │ (None, 64, 128, 32)  │            0 │ up_block2_bn1[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_conv2        │ (None, 64, 128, 32)  │        9,248 │ up_block2_activati… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_bn2          │ (None, 64, 128, 32)  │          128 │ up_block2_conv2[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_activation2  │ (None, 64, 128, 32)  │            0 │ up_block2_bn2[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ output_layer (Conv2D)  │ (None, 64, 128, 5)   │          165 │ up_block2_activati… │    Y    │
# └────────────────────────┴──────────────────────┴──────────────┴─────────────────────┴─────────┘
#  Total params: 473,669 (1.81 MB)
#  Trainable params: 472,389 (1.80 MB)
#  Non-trainable params: 1,280 (5.00 KB)

# %%
# Mean IntersectionOverUnion as metric
mean_iou = tfk.metrics.MeanIoU(num_classes=NUM_CLASSES, ignore_class=0, sparse_y_pred=False)

# Compile the model
print("Compiling model...")
model.compile(optimizer=tf.keras.optimizers.AdamW(LEARNING_RATE), loss=tf.keras.losses.SparseCategoricalCrossentropy(), metrics=["accuracy", mean_iou])
print("Model compiled!")
# Out:
# Compiling model...
# Model compiled!

# %%
# Setup callbacks
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_mean_io_u',
    mode='max',
    patience=PATIENCE,
    restore_best_weights=True
)

# %% [markdown]
# ## 💪 Train the network

# %%
# Train the model
history = model.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=val_dataset,
    callbacks=[early_stopping],#, viz_callback],
    verbose=1
).history

# Calculate and print the final validation accuracy
final_val_meanIoU = round(max(history['val_mean_io_u'])* 100, 2)
print(f'Final validation Mean Intersection Over Union: {final_val_meanIoU}%')

# Save the trained model to a file with the accuracy included in the filename
model_filename = 'UNet_'+str(final_val_meanIoU)+'.keras'
model.save(model_filename)

# Delete the model to free up resources
del model
# Out:
# Epoch 1/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 50s 751ms/step - accuracy: 0.3506 - loss: 1.5337 - mean_io_u: 0.1621 - val_accuracy: 0.0384 - val_loss: 22.6630 - val_mean_io_u: 0.0124
# Epoch 2/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - accuracy: 0.5609 - loss: 1.1470 - mean_io_u: 0.2865 - val_accuracy: 0.3853 - val_loss: 1.9795 - val_mean_io_u: 0.1857
# Epoch 3/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - accuracy: 0.6115 - loss: 1.0157 - mean_io_u: 0.3264 - val_accuracy: 0.5279 - val_loss: 1.1903 - val_mean_io_u: 0.2819
# Epoch 4/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.6412 - loss: 0.9303 - mean_io_u: 0.3557 - val_accuracy: 0.6035 - val_loss: 1.1696 - val_mean_io_u: 0.3013
# Epoch 5/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.6479 - loss: 0.9151 - mean_io_u: 0.3605 - val_accuracy: 0.5110 - val_loss: 1.3693 - val_mean_io_u: 0.2432
# Epoch 6/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - accuracy: 0.6711 - loss: 0.8525 - mean_io_u: 0.3772 - val_accuracy: 0.5597 - val_loss: 1.3053 - val_mean_io_u: 0.2742
# Epoch 7/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - accuracy: 0.6659 - loss: 0.8500 - mean_io_u: 0.3757 - val_accuracy: 0.5615 - val_loss: 1.3065 - val_mean_io_u: 0.2840
# Epoch 8/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - accuracy: 0.6755 - loss: 0.8333 - mean_io_u: 0.3903 - val_accuracy: 0.6400 - val_loss: 1.0208 - val_mean_io_u: 0.3069
# Epoch 9/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - accuracy: 0.6682 - loss: 0.8432 - mean_io_u: 0.3785 - val_accuracy: 0.6537 - val_loss: 0.9813 - val_mean_io_u: 0.3263
# Epoch 10/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - accuracy: 0.6872 - loss: 0.8015 - mean_io_u: 0.3980 - val_accuracy: 0.6305 - val_loss: 1.2176 - val_mean_io_u: 0.3304
# Epoch 11/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - accuracy: 0.6980 - loss: 0.7756 - mean_io_u: 0.4048 - val_accuracy: 0.6411 - val_loss: 0.9827 - val_mean_io_u: 0.3275
# Epoch 12/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - accuracy: 0.6960 - loss: 0.7820 - mean_io_u: 0.4037 - val_accuracy: 0.3422 - val_loss: 1.8066 - val_mean_io_u: 0.1078
# Epoch 13/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - accuracy: 0.6989 - loss: 0.7698 - mean_io_u: 0.4044 - val_accuracy: 0.6272 - val_loss: 1.1075 - val_mean_io_u: 0.3206
# Epoch 14/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.6994 - loss: 0.7702 - mean_io_u: 0.4067 - val_accuracy: 0.5953 - val_loss: 1.1816 - val_mean_io_u: 0.3020
# Epoch 15/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - accuracy: 0.7143 - loss: 0.7359 - mean_io_u: 0.4182 - val_accuracy: 0.7161 - val_loss: 0.8357 - val_mean_io_u: 0.3912
# Epoch 16/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.7093 - loss: 0.7376 - mean_io_u: 0.4200 - val_accuracy: 0.6049 - val_loss: 1.2618 - val_mean_io_u: 0.3048
# Epoch 17/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.7216 - loss: 0.7148 - mean_io_u: 0.4257 - val_accuracy: 0.6701 - val_loss: 1.0237 - val_mean_io_u: 0.3622
# Epoch 18/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - accuracy: 0.7247 - loss: 0.7057 - mean_io_u: 0.4275 - val_accuracy: 0.6200 - val_loss: 1.0844 - val_mean_io_u: 0.3217
# Epoch 19/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.7192 - loss: 0.7225 - mean_io_u: 0.4229 - val_accuracy: 0.7260 - val_loss: 0.8146 - val_mean_io_u: 0.4142
# Epoch 20/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.7323 - loss: 0.6907 - mean_io_u: 0.4371 - val_accuracy: 0.6614 - val_loss: 0.9482 - val_mean_io_u: 0.3650
# Epoch 21/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - accuracy: 0.7247 - loss: 0.7116 - mean_io_u: 0.4302 - val_accuracy: 0.7142 - val_loss: 0.9068 - val_mean_io_u: 0.4045
# Epoch 22/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.7288 - loss: 0.6951 - mean_io_u: 0.4352 - val_accuracy: 0.6737 - val_loss: 1.0167 - val_mean_io_u: 0.3626
# Epoch 23/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.7415 - loss: 0.6590 - mean_io_u: 0.4431 - val_accuracy: 0.7428 - val_loss: 0.6742 - val_mean_io_u: 0.4395
# Epoch 24/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - accuracy: 0.7400 - loss: 0.6659 - mean_io_u: 0.4446 - val_accuracy: 0.6927 - val_loss: 0.8948 - val_mean_io_u: 0.3923
# Epoch 25/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - accuracy: 0.7442 - loss: 0.6588 - mean_io_u: 0.4522 - val_accuracy: 0.5161 - val_loss: 1.5255 - val_mean_io_u: 0.2448
# Epoch 26/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.7441 - loss: 0.6647 - mean_io_u: 0.4416 - val_accuracy: 0.7391 - val_loss: 0.7034 - val_mean_io_u: 0.4467
# Epoch 27/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 130ms/step - accuracy: 0.7445 - loss: 0.6543 - mean_io_u: 0.4438 - val_accuracy: 0.7252 - val_loss: 0.8490 - val_mean_io_u: 0.4069
# Epoch 28/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.7570 - loss: 0.6262 - mean_io_u: 0.4596 - val_accuracy: 0.7186 - val_loss: 0.7893 - val_mean_io_u: 0.4096
# Epoch 29/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.7553 - loss: 0.6309 - mean_io_u: 0.4583 - val_accuracy: 0.7010 - val_loss: 0.8612 - val_mean_io_u: 0.3680
# Epoch 30/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - accuracy: 0.7541 - loss: 0.6421 - mean_io_u: 0.4541 - val_accuracy: 0.6954 - val_loss: 0.8565 - val_mean_io_u: 0.3840
# Epoch 31/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.7491 - loss: 0.6413 - mean_io_u: 0.4490 - val_accuracy: 0.7098 - val_loss: 0.8647 - val_mean_io_u: 0.3909
# Epoch 32/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.7587 - loss: 0.6206 - mean_io_u: 0.4666 - val_accuracy: 0.7704 - val_loss: 0.6213 - val_mean_io_u: 0.4523
# Epoch 33/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.7623 - loss: 0.6123 - mean_io_u: 0.4586 - val_accuracy: 0.7262 - val_loss: 0.7274 - val_mean_io_u: 0.4229
# Epoch 34/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.7641 - loss: 0.6078 - mean_io_u: 0.4624 - val_accuracy: 0.7345 - val_loss: 0.6995 - val_mean_io_u: 0.4251
# Epoch 35/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.7574 - loss: 0.6205 - mean_io_u: 0.4537 - val_accuracy: 0.7218 - val_loss: 0.8882 - val_mean_io_u: 0.4192
# Epoch 36/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.7517 - loss: 0.6409 - mean_io_u: 0.4511 - val_accuracy: 0.6273 - val_loss: 1.0844 - val_mean_io_u: 0.3626
# Epoch 37/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - accuracy: 0.7668 - loss: 0.5952 - mean_io_u: 0.4656 - val_accuracy: 0.7131 - val_loss: 0.7732 - val_mean_io_u: 0.4156
# Epoch 38/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.7756 - loss: 0.5783 - mean_io_u: 0.4746 - val_accuracy: 0.6959 - val_loss: 0.8747 - val_mean_io_u: 0.3763
# Epoch 39/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.7705 - loss: 0.5879 - mean_io_u: 0.4649 - val_accuracy: 0.7307 - val_loss: 0.7829 - val_mean_io_u: 0.4087
# Epoch 40/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - accuracy: 0.7758 - loss: 0.5787 - mean_io_u: 0.4714 - val_accuracy: 0.6057 - val_loss: 1.3916 - val_mean_io_u: 0.3130
# Epoch 41/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - accuracy: 0.7797 - loss: 0.5695 - mean_io_u: 0.4770 - val_accuracy: 0.6934 - val_loss: 0.9392 - val_mean_io_u: 0.3756
# Epoch 42/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - accuracy: 0.7687 - loss: 0.5924 - mean_io_u: 0.4630 - val_accuracy: 0.7354 - val_loss: 0.6899 - val_mean_io_u: 0.4261
# Final validation Mean Intersection Over Union: 45.23%

# %%
# Plot and display training and validation loss
plt.figure(figsize=(18, 3))
plt.plot(history['loss'], label='Training', alpha=0.8, color='#ff7f0e', linewidth=2)
plt.plot(history['val_loss'], label='Validation', alpha=0.9, color='#5a9aa5', linewidth=2)
plt.title('Cross Entropy')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# Plot and display training and validation accuracy
plt.figure(figsize=(18, 3))
plt.plot(history['accuracy'], label='Training', alpha=0.8, color='#ff7f0e', linewidth=2)
plt.plot(history['val_accuracy'], label='Validation', alpha=0.9, color='#5a9aa5', linewidth=2)
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# Plot and display training and validation mean IoU
plt.figure(figsize=(18, 3))
plt.plot(history['mean_io_u'], label='Training', alpha=0.8, color='#ff7f0e', linewidth=2)
plt.plot(history['val_mean_io_u'], label='Validation', alpha=0.9, color='#5a9aa5', linewidth=2)
plt.title('Mean Intersection over Union')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ## 🔎 Inference using the model

# %%
# Load UNet model without compiling
model_filename = 'UNet_45.23.keras'
model = tfk.models.load_model(model_filename, compile=False)

# Compile the model with specified loss, optimizer, and metrics
model.compile(optimizer=tf.keras.optimizers.AdamW(LEARNING_RATE), loss=tf.keras.losses.SparseCategoricalCrossentropy(), metrics=["accuracy", mean_iou])

# Print a detailed summary of the model with expanded nested layers and trainable parameters.
model.summary(expand_nested=True, show_trainable=True)

# Generate and display a graphical representation of the model architecture.
tf.keras.utils.plot_model(model, show_trainable=True, expand_nested=True, dpi=70)
# Out:
# Model: "UNet"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ Layer (type)           ┃ Output Shape         ┃      Param # ┃ Connected to        ┃ Traina… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ input_layer            │ (None, 64, 128, 1)   │            0 │ -                   │    -    │
# │ (InputLayer)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_conv1      │ (None, 64, 128, 32)  │          320 │ input_layer[0][0]   │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_bn1        │ (None, 64, 128, 32)  │          128 │ down_block1_conv1[… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_activatio… │ (None, 64, 128, 32)  │            0 │ down_block1_bn1[0]… │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_conv2      │ (None, 64, 128, 32)  │        9,248 │ down_block1_activa… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_bn2        │ (None, 64, 128, 32)  │          128 │ down_block1_conv2[… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_activatio… │ (None, 64, 128, 32)  │            0 │ down_block1_bn2[0]… │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ max_pooling2d          │ (None, 32, 64, 32)   │            0 │ down_block1_activa… │    -    │
# │ (MaxPooling2D)         │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_conv1      │ (None, 32, 64, 64)   │       18,496 │ max_pooling2d[0][0] │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_bn1        │ (None, 32, 64, 64)   │          256 │ down_block2_conv1[… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_activatio… │ (None, 32, 64, 64)   │            0 │ down_block2_bn1[0]… │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_conv2      │ (None, 32, 64, 64)   │       36,928 │ down_block2_activa… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_bn2        │ (None, 32, 64, 64)   │          256 │ down_block2_conv2[… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_activatio… │ (None, 32, 64, 64)   │            0 │ down_block2_bn2[0]… │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ max_pooling2d_1        │ (None, 16, 32, 64)   │            0 │ down_block2_activa… │    -    │
# │ (MaxPooling2D)         │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckconv1        │ (None, 16, 32, 128)  │       73,856 │ max_pooling2d_1[0]… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckbn1          │ (None, 16, 32, 128)  │          512 │ bottleneckconv1[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckactivation1  │ (None, 16, 32, 128)  │            0 │ bottleneckbn1[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckconv2        │ (None, 16, 32, 128)  │      147,584 │ bottleneckactivati… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckbn2          │ (None, 16, 32, 128)  │          512 │ bottleneckconv2[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckactivation2  │ (None, 16, 32, 128)  │            0 │ bottleneckbn2[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_sampling2d          │ (None, 32, 64, 128)  │            0 │ bottleneckactivati… │    -    │
# │ (UpSampling2D)         │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ concatenate            │ (None, 32, 64, 192)  │            0 │ up_sampling2d[0][0… │    -    │
# │ (Concatenate)          │                      │              │ down_block2_activa… │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_conv1        │ (None, 32, 64, 64)   │      110,656 │ concatenate[0][0]   │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_bn1          │ (None, 32, 64, 64)   │          256 │ up_block1_conv1[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_activation1  │ (None, 32, 64, 64)   │            0 │ up_block1_bn1[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_conv2        │ (None, 32, 64, 64)   │       36,928 │ up_block1_activati… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_bn2          │ (None, 32, 64, 64)   │          256 │ up_block1_conv2[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_activation2  │ (None, 32, 64, 64)   │            0 │ up_block1_bn2[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_sampling2d_1        │ (None, 64, 128, 64)  │            0 │ up_block1_activati… │    -    │
# │ (UpSampling2D)         │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ concatenate_1          │ (None, 64, 128, 96)  │            0 │ up_sampling2d_1[0]… │    -    │
# │ (Concatenate)          │                      │              │ down_block1_activa… │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_conv1        │ (None, 64, 128, 32)  │       27,680 │ concatenate_1[0][0] │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_bn1          │ (None, 64, 128, 32)  │          128 │ up_block2_conv1[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_activation1  │ (None, 64, 128, 32)  │            0 │ up_block2_bn1[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_conv2        │ (None, 64, 128, 32)  │        9,248 │ up_block2_activati… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_bn2          │ (None, 64, 128, 32)  │          128 │ up_block2_conv2[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_activation2  │ (None, 64, 128, 32)  │            0 │ up_block2_bn2[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ output_layer (Conv2D)  │ (None, 64, 128, 5)   │          165 │ up_block2_activati… │    Y    │
# └────────────────────────┴──────────────────────┴──────────────┴─────────────────────┴─────────┘
#  Total params: 473,669 (1.81 MB)
#  Trainable params: 472,389 (1.80 MB)
#  Non-trainable params: 1,280 (5.00 KB)

# %%
# Evaluate the model on the test set and print the results
test_loss, test_accuracy, test_mean_iou = model.evaluate(test_dataset, verbose=1, batch_size=10)
print(f'Test Accuracy: {round(test_accuracy, 4)}')
print(f'Test Mean Intersection over Union: {round(test_mean_iou, 4)}')
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.7233 - loss: 0.7309 - mean_io_u: 0.4276
# Test Accuracy: 0.7422
# Test Mean Intersection over Union: 0.4305

# %%
preds_first = model.predict(test_img)
preds_first = np.argmax(preds_first, axis=-1)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 288ms/step

# %%
for index in range(50):
  plt.figure(figsize=(8,4))
  plt.subplot(1,3,1)
  plt.imshow(test_img[index], cmap='gray')
  plt.axis('off')
  plt.title("Input Image")
  plt.subplot(1,3,2)
  plt.imshow(test_lbl[index], cmap='inferno',vmin=0,vmax=4)
  plt.axis('off')
  plt.title("Input Label")
  plt.subplot(1,3,3)
  plt.imshow(preds_first[index], cmap='inferno',vmin=0,vmax=4)
  plt.axis('off')
  plt.title("Pred label")
  plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Flatten the label arrays for comparison
true_labels = test_lbl.flatten()
predicted_labels = preds_first.flatten()

# Compute the confusion matrix
num_classes = 5  # Adjust this based on the number of classes
conf_matrix = confusion_matrix(true_labels, predicted_labels, labels=np.arange(num_classes))

# Visualize the confusion matrix
plt.figure(figsize=(8, 6))
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=np.arange(num_classes))
disp.plot(cmap='Blues')  # Use scientific notation for

# %% [markdown]
# ## 📊 Prepare Your Submission
#
# In our Kaggle competition, submissions are made as `csv` files. To create a proper `csv` file, you need to flatten your predictions and include an `id` column as the first column of your dataframe. To maintain consistency between your results and our solution, please avoid shuffling the test set. The code below demonstrates how to prepare the `csv` file from your model predictions.

# %%
# If model_filename is not defined, load the most recent model from Google Drive
if "model_filename" not in globals() or model_filename is None:
    files = [f for f in os.listdir('.') if os.path.isfile(f) and f.startswith('model_') and f.endswith('.keras')]
    files.sort(key=lambda x: os.path.getmtime(x), reverse=True)
    if files:
        model_filename = files[0]
    else:
        raise FileNotFoundError("No model files found in the current directory.")

# %%
print(model_filename)
# Out:
# UNet_45.23.keras

# %%
# Load model
model = tfk.models.load_model(model_filename)
print(f"Model loaded from {model_filename}")
# Out:
# Model loaded from UNet_45.23.keras

# %%
# Prediction
preds = model.predict(X_test)
preds = np.argmax(preds, axis=-1)
print(f"Predictions shape: {preds.shape}")
# Out:
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step
# Predictions shape: (10022, 64, 128)

# %%
plt.figure()
plt.imshow(X_test[0])
plt.figure()
plt.imshow(preds[0], cmap='inferno',vmin=0,vmax=4)

# %%
import pandas as pd

def y_to_df(y) -> pd.DataFrame:
    """Converts segmentation predictions into a DataFrame format for Kaggle."""
    n_samples = len(y)
    y_flat = y.reshape(n_samples, -1)
    df = pd.DataFrame(y_flat)
    df["id"] = np.arange(n_samples)
    cols = ["id"] + [col for col in df.columns if col != "id"]
    return df[cols]

# %%
# Create and download the csv submission file
timestep_str = model_filename.replace("model_", "").replace(".keras", "")
submission_filename = f"submission_{timestep_str}.csv"
submission_df = y_to_df(preds)
submission_df.to_csv(submission_filename, index=False)

from google.colab import files
files.download(submission_filename)
